# %%
import pandas as pd

# %%
ufo = pd.read_csv('../data-repo/ufo.csv')

# %%
pd.isnull(ufo).head()
# Out:
#     City  Colors Reported  Shape Reported  State   Time
# 0  False             True           False  False  False
# 1  False             True           False  False  False
# 2  False             True           False  False  False
# 3  False             True           False  False  False
# 4  False             True           False  False  False

# %%
ufo.isnull().head()
# Out:
#     City  Colors Reported  Shape Reported  State   Time
# 0  False             True           False  False  False
# 1  False             True           False  False  False
# 2  False             True           False  False  False
# 3  False             True           False  False  False
# 4  False             True           False  False  False

# %%
ufo['Colors Reported'].isnull().head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: Colors Reported, dtype: bool

# %%
ufo.loc[0:4, :]
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.iloc[0:4, 0:]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3      Abilene             NaN           DISK    KS   6/1/1931 13:00

# %%
# 随机
ufo.sample(n=4)
# Out:
#                   City Colors Reported Shape Reported State             Time
# 17493      Glenn Ellyn             NaN           OVAL    IL  9/21/2000 21:25
# 15613           Clovis             NaN          LIGHT    CA    1/1/2000 5:00
# 6060          Hooksett             NaN            NaN    NH  5/15/1989 14:00
# 4078   Court House Bay             NaN          LIGHT    NC   6/1/1979 22:00

# %%
train = ufo.sample(frac=0.75, random_state=99)
test = ufo.loc[~ufo.index.isin(train.index), :]
test
# Out:
#                        City Colors Reported Shape Reported State  \
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 8                   Eklutna             NaN          CIGAR    AK
# 11                 Waterloo             NaN       FIREBALL    AL
# 13                   Keokuk             NaN           OVAL    IA
# 17                Hapeville             NaN            NaN    GA
# 32                  Ft. Lee             NaN          CIGAR    VA
# 35            Winston-Salem             NaN           DISK    NC
# 36               Portsmouth             RED      FORMATION    VA
# 43                    Alice             NaN           DISK    TX
# 44                Blairsden           GREEN         SPHERE    CA
# 49                   Conroe             NaN          OTHER    TX
# 53                   Minden             NaN            NaN    LA
# ...
